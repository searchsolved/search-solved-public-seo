# %% [markdown]
# <a href="https://colab.research.google.com/github/searchsolved/search-solved-public-seo/blob/main/Visualise_Search_Console_Coverage_Reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualise Search Console Coverage Reports
# Spot issues fast by visualising your Search Console Coverage Reports. Especially useful to visualise low quality folder paths at a glance (crawled, not indexed).
#
# ## How to use:
# Run all cells and upload a Search Console Coverage Report in *Excel* format.
#
# ### Options:
# Option to set a starting folder depth (Useful to step through cctld folders)
#
# ### Output
# Exports a Treemap and Sunburst Chart from the coverage report
#
# *   Interactive Treemap .html file
# *   Interactive Sunburst .html file
#
# https://twitter.com/LeeFootSEO <--- Follow for more scripts like this.

# %%
# set optional folder depth offset # default = 1
folder_start = 1

# %%
# Custom Title for Reports
title = "Coverage Report"

# %%
# !pip install pandas
# !pip install pip install plotly==5.0.0
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (19.3.1)
# Requirement already satisfied: install in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Collecting plotly==5.0.0
#   Downloading https://files.pythonhosted.org/packages/84/ff/cc3f54a0822987a5ac277de0deb018104f12aadd933cedd97b600894ebcc/plotly-5.0.0-py2.py3-none-any.whl (19.1MB)
#      |████████████████████████████████| 19.1MB 150kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==5.0.0) (1.15.0)
# Collecting tenacity>=6.2.0
#   Downloading https://files.pythonhosted.org/packages/41/ee/d6eddff86161c6a3a1753af4a66b06cbc508d3b77ca4698cd0374cd66531/tenacity-7.0.0-py2.py3-none-any.whl
# Installing collected packages: tenacity, plotly
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# Successfully installed plotly-5.0.0 tenacity-7.0.0

# %%
import re
import urllib.parse as urlparse
from collections import Counter
from glob import glob

import matplotlib.pyplot as plt
import nltk
import pandas as pd
import plotly.express as px
from nltk.corpus import stopwords
from wordcloud import WordCloud
from google.colab import files

# %%
# upload any Search Console Coverage Report - Must be an Excel file export - csv not accepted!
uploaded = files.upload()
# Out:
#      <input type="file" id="files-477a920d-46ac-4049-87cf-34c885d34b2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-477a920d-46ac-4049-87cf-34c885d34b2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving costa.xlsx to costa.xlsx

# %%
filename = list(uploaded.keys())[0]  # get the filename from the upload
df = pd.read_excel(filename, 'Table')  # choose the right sheet from Excel
nltk.download('stopwords')
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                                  URL Last crawled
# 0  https://www.wilko.com/en-uk/home/kitchen-dinin...   2021-06-22
# 1  https://www.wilko.com/en-uk/pets/cat/cat-groom...   2021-06-22
# 2  https://www.wilko.com/en-uk/health-beauty/dent...   2021-06-22
# 3  https://www.wilko.com/en-uk/toys/outdoor-toys/...   2021-06-22
# 4                         https://www.wilko.com/help   2021-06-22

# %%
df['total_urls'] = 1  # used to count in the grouping
df["protocol"], df["domain"], df["path"], df["query"], df["fragment"] = zip(*df["URL"].map(urlparse.urlsplit))

# make temp df to split with expand=true and then merge back by the index.
df['path'] = df['path'].apply(lambda x: x.replace("//", "/"))
df2 = df['path'].str.split('/', expand=True)
df2 = df2.fillna("missing_value")
df = pd.merge(df, df2, left_index=True, right_index=True)
next_folder = folder_start + 1

# %%
# concat 0 + 1 path to merge and group by each depth. e.g. level1  + level 2 together.
df['level_1+2'] = "/" + df[next_folder]

# %%
cnt = Counter()
english_stopwords = set(stopwords.words('english'))

for path in df['level_1+2']:
  words = re.split("[-/]", path)
  for word in words:
    if len(word) > 0 and word not in english_stopwords and not word.isdigit():
      cnt[word] += 1

cnt.most_common(25)

word_cloud = [x[0] for x in cnt.most_common(25)]
word_cloud_obj = WordCloud(max_words=25, background_color="white").generate(" ".join(word_cloud))

plt.imshow(word_cloud_obj, interpolation='bilinear')
plt.axis("off")
plt.savefig('word_cloud.png', dpi=300)
plt.show()

# %%
try:
    treemap_fig = px.treemap(df, path=[px.Constant(title), folder_start, next_folder, 'URL'],values='total_urls', color_discrete_sequence=px.colors.qualitative.Antique)
except ValueError:
    print("Not all URLs can go to a url depth of", folder_start, "using default depths instead.")
    folder_start = 1
    next_folder = 2
    treemap_fig = px.treemap(df, path=[px.Constant(title), folder_start, next_folder, 'URL'], values='total_urls', color_discrete_sequence=px.colors.qualitative.Antique)
    pass

treemap_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.1.0.min.js"></script>                <div id="6ad9ae96-9f5c-42b0-836b-1f7b0eea4d06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ad9ae96-9f5c-42b0-836b-1f7b0eea4d06")) {                    Plotly.newPlot(                        "6ad9ae96-9f5c-42b0-836b-1f7b0eea4d06",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>total_urls=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Coverage Report//missing_value/https://www.wilko.com/","Coverage Report/en-uk//https://www.wilko.com/en-uk/","Coverage Report/en-uk/home/https://www.wilko.com/en-uk//home/kitchen-dining/kitchen-collections/elegant-pretty-kitchen/c/3275","Coverage Report/en-uk//https://www.wilko.com/en-uk/?logout=true","Coverage Report/en-uk/Coronavirus-COVID-19-Store-Information/https://www.wilko.com/en-uk/Coronavirus-COVID-19-Store-Information","Coverage Report/en-uk/Laybuy/https://www.wilko.com/en-uk/Laybuy","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-feeding/c/650","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-health-care/c/677","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-toiletries/c/670","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/c/649","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/dummies-soothers/c/666","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/nappies-wipes/c/662","Coverage Report/en-uk/collections/https://www.wilko.com/en-uk/collections/floorcare/c/5210","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/c/464","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/c/899","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-accessories/c/919","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-cleaning/c/900","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-cleaning/pressure-washers/c/1479","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-maintenance/c/905","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/c/502","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/fillers-sealants/c/1357","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/glues-adhesives/c/516","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/paint-brushes-rollers/c/503","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/scrapers-trowels-knives/c/522","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/wallpapering-tools/c/506","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/batteries-chargers/c/599","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/c/595","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/door-bells-alarms-sensors/c/609","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/extension-leads-cable-reels/c/605","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/smart-home-technology/c/1398","Coverage Report/en-uk/decorating-diy/ht ...

# %%
# plot a sun burst
try:
    sunburst_fig = px.sunburst(df, path=[px.Constant(title), folder_start, next_folder, 'URL'],values='total_urls', color_discrete_sequence=px.colors.qualitative.Antique)
except ValueError:
    print("Not all URLs can go to a url depth of", folder_start, "using default depths instead.")
    folder_start = 1
    next_folder = 2
    sun_burst_fig = px.treemap(df, path=[px.Constant("Coverage Report", ), folder_start, next_folder, 'URL'], values='total_urls', color_discrete_sequence=px.colors.qualitative.Antique)
    pass

sunburst_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.1.0.min.js"></script>                <div id="5019cfbe-84bc-4d7e-a93c-db44796938f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5019cfbe-84bc-4d7e-a93c-db44796938f7")) {                    Plotly.newPlot(                        "5019cfbe-84bc-4d7e-a93c-db44796938f7",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>total_urls=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Coverage Report//missing_value/https://www.wilko.com/","Coverage Report/en-uk//https://www.wilko.com/en-uk/","Coverage Report/en-uk/home/https://www.wilko.com/en-uk//home/kitchen-dining/kitchen-collections/elegant-pretty-kitchen/c/3275","Coverage Report/en-uk//https://www.wilko.com/en-uk/?logout=true","Coverage Report/en-uk/Coronavirus-COVID-19-Store-Information/https://www.wilko.com/en-uk/Coronavirus-COVID-19-Store-Information","Coverage Report/en-uk/Laybuy/https://www.wilko.com/en-uk/Laybuy","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-feeding/c/650","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-health-care/c/677","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/baby-toiletries/c/670","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/c/649","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/dummies-soothers/c/666","Coverage Report/en-uk/baby-pregnancy/https://www.wilko.com/en-uk/baby-pregnancy/nappies-wipes/c/662","Coverage Report/en-uk/collections/https://www.wilko.com/en-uk/collections/floorcare/c/5210","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/c/464","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/c/899","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-accessories/c/919","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-cleaning/c/900","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-cleaning/pressure-washers/c/1479","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/car-care/car-maintenance/c/905","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/c/502","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/fillers-sealants/c/1357","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/glues-adhesives/c/516","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/paint-brushes-rollers/c/503","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/scrapers-trowels-knives/c/522","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/decorating-tools-accessories/wallpapering-tools/c/506","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/batteries-chargers/c/599","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/c/595","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/door-bells-alarms-sensors/c/609","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/extension-leads-cable-reels/c/605","Coverage Report/en-uk/decorating-diy/https://www.wilko.com/en-uk/decorating-diy/electrical/smart-home-technology/c/1398","Coverage Report/en-uk/decorating-diy/ht ...

# %% [markdown]
# Remember to Click ''Allow Downloading of Multiple Files' in Chrome when Prompted!

# %%
# download the sunburst .html chart
sunburst_fig.write_html("coverage_report_sunburst.html")
files.download("coverage_report_sunburst.html")

# %%
# download the treemap .html chart
treemap_fig.write_html("coverage_report_treemap.html")
files.download("coverage_report_treemap.html")

# %%
# download the word_cloud chart
files.download("word_cloud.png")
